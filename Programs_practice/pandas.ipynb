# %% [markdown]
# pandas

# %%
import pandas as pd

# %%
p = pd.Series([1,3]) #series is datastructre in Python
print (p)
# Out:
# 0    1
# 1    3
# dtype: int64

# %%
p = pd.Series([10,30,50], index=['a','b','c'])
print (p)
# Out:
# a    10
# b    30
# c    50
# dtype: int64

# %%
print(p.loc['b']) # using location or index name
print(p.iloc[2]) # using index value
# Out:
# 30
# 50
