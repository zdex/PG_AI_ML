# %%
def PizzaMachine(x,y):
    print('veggie is: '  + x)
    print('sause is: ' + y)
print('pizza is ready')
# Out:
# pizza is ready
# veggie is: 1
# sause is: 2

# %%
PizzaMachine('1', '2')
# Out:
# veggie is: 1
# sause is: 2

# %%
def cum_sum(*num):
    total = 0
    counter = 0
    list = [x.upper() + str(counter) for x in num counter += 1 ]
    counter += 1
    print(list)
    for i in num:
        print(i)
    return total
# Out:
#   Cell In[39], line 4
#     list = [x.upper() + str(counter) for x in num counter += 1 ]
#                                                   ^
# SyntaxError: invalid syntax

# %%
def cum_sum(*num):
    counter = 0
    result = []

    for x in num:
        result.append(x.upper() + str(counter))
        counter += 1
        

    print(result)

    for i in num:
        print(i)

    return counter

cum_sum('a', 'b', 'c')
# Out:
# ['A0', 'B1', 'C2']
# a
# b
# c
# 3

# %%
def names(**namedic):
    print(namedic)

names(first = 'ram', sec = 'gaurav')
# Out:
# {'first': 'ram', 'sec': 'gaurav'}

# %%
def names(*age, **namedic):
    print("Positional arguments: ", age)
    print("Keyword arguments: ", namedic)

names(1, 2, first = 'ram', sec = 'gaurav')
# Out:
# Positional arguments:  (1, 2)
# Keyword arguments:  {'first': 'ram', 'sec': 'gaurav'}

# %%
square = lambda x: x*x
print(square(3))
# Out:
# 9

# %%
mul = lambda x,y: x*y
print(mul(3,5))
# Out:
# 15

# %%
names = ["gaurav", "alex", "mira"]

result = list(map(str.upper, names))
print(result)
# Out:
# ['GAURAV', 'ALEX', 'MIRA']

# %%
nums = [1, 2, 3, 4]

result = list(map(lambda x: x * 10, nums))
print(result)
# Out:
# [10, 20, 30, 40]

# %%
import modules 
print(modules.myname("gaurav"))
# Out:
# my name is: gaurav
