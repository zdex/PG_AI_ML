# %%
print("hello world!")
# my first program
# Out:
# hello world!

# %%
# Math Operations
2 + 3
# Out:
# 5

# %%
10 * 2 - 5
# Out:
# 15

# %%
2 ** 4
# Out:
# 16

# %% [markdown]
# Strings

# %%
'single quote'
# Out:
# 'single quote'

# %%
"double quote"
# Out:
# 'double quote'

# %%
"double quote wraps lot's of quotes"
# Out:
# "double quote wraps lot's of quotes"

# %% [markdown]
# # Variables
#
# Variables are containers for storing values

# %%
x = 'hi'
y = 5
print(x)
print(y)
print(x,y)
# Out:
# hi
# 5
# hi 5

# %%
# Assign one value to multiple variables
x=y=z=10
print(x,y,z)
# Out:
# 10 10 10

# %%
a,b,c = 11,12,13
print(a,b,c)
# Out:
# 11 12 13

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a = 'hello'
print(type(a))
# Out:
# <class 'str'>

# %%
print(a)
# Out:
# hello

# %% [markdown]
# Variables Naming Limitation:
# Cannot start with a number or special character

# %%
a = 4
A = 'Sally'
print(a)
print(A)
# Out:
# 4
# Sally

# %% [markdown]
# ## Data Types in Python
#
# - Numeric (Integer, Float, Complex Numbers)
# - Strings
# - List
# - Tuple
# - Dictionary
# - Set
# - Boolean

# %%
# Numerical Datatypes:

# %%
a = 4
print(a)
print(id(a))
# Out:
# 4
# 140732586959880

# %%
a = 6
print(a)
print(id(a))
# Out:
# 6
# 140732586959944

# %%
type(a)
# Out:
# int

# %%
a = 4

# %%
id(a)
# Out:
# 140732586959880

# %%
# Type Conversion
x = 1
y = 2.8
z = '3'
print(type(x))
print(type(y))
print(type(z))

x = int(1)
y = int(2.8)
z = int('3')
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x = str(1)
y = str(2.8)
z = str('3')
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
print(x,y,z)
# Out:
# 1 2.8 3

# %% [markdown]
# ## String
#
# String are immutable and are sequential data types

# %%
str1 = 'hello'
str2 = "hello"
str3 = '''he
l
l
o''' # triple quote is used with multiline text data is used.

# %%
str1 == str2
# Out:
# True

# %%
str3
# Out:
# 'he\nl\nl\no'

# %%
'''triple quote is used 
with multiline text 
data is used.'''


str1 = 'hello'
str2 = "hello"
str3 = '''he
l
l
o'''

# %%
str = 'Good Morning'

# %%
len(str)
# Out:
# 12

# %%
str[0]
# Out:
# 'G'

# %%
str[11]
# Out:
# 'g'

# %% [markdown]
# # Slicing of the String
#
# [start:stop:step] -> Positive Index (point moves from left to right)

# %%
str[0:4]
# Out:
# 'Good'

# %%
str[0::2]
# Out:
# 'Go onn'

# %%
str
# Out:
# 'Good'

# %%
str[5:]
# Out:
# 'Morning'

# %%
str[::-1]
# Out:
# 'gninroM dooG'

# %%
str[0:11:-1]
# Out:
# ''

# %%
str[11::-1]
# Out:
# 'gninroM dooG'

# %%
a = 'my name is vineet and it is a pleasant day'
a.count('is')
# Out:
# 2

# %%
a.split('and')
# Out:
# ['my name is vineet ', ' it is a pleasant day']

# %%
a
# Out:
# 'my name is vineet and it is a pleasant day'

# %%
a.replace('vineet', 'john')
# Out:
# 'my name is john and it is a pleasant day'

# %%
# String Concatenation (+)

a = 'Hello'
b = 'World'
a+b
# Out:
# 'HelloWorld'

# %%
a+" "+b
# Out:
# 'Hello World'

# %%
# String and Number cannot be concatenated

a = 'my age is'
b = '32'

a +" "+ b
# Out:
# 'my age is 32'

# %%
# F String (another alternate is format - HW - explore format method)

name = 'Bob'
age = '30'

greetings = f'my name is {name} and my age is {age} years.'
print(greetings)
# Out:
# my name is Bob and my age is 30 years.
