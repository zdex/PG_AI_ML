# %%
import Currency_module1 # import the custom module

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\vinee\\Python ML\\Python\\ED Class\\Week 2'

# %%
print(Currency_module1.rs_to_dollar(900))
print(Currency_module1.dollar_to_rs(10))
# Out:
# 10.0
# 900

# %%
#Use alias
import Currency_module1 as currency

print(currency.rs_to_dollar(830))
print(currency.dollar_to_rs(10))
# Out:
# 10.0
# 830

# %%
#Import specific functions
from Currency_module1 import rs_to_dollar

print(rs_to_dollar(830))
print(dollar_to_rs(10))
# Out:
# 10.0
# 830
